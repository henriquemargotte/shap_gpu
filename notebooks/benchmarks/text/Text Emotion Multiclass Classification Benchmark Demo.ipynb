# %% [markdown]
# # Text Data Explanation Benchmarking: Emotion Multiclass Classification

# %% [markdown]
# This notebook demonstrates how to use the benchmark utility to benchmark the performance of an explainer for text data. In this demo, we showcase explanation performance for partition explainer on an Emotion Multiclass Classification model. The metrics used to evaluate are "keep positive" and "keep negative". The masker used is Text Masker.
#
# The new benchmark utility uses the new API with MaskedModel as wrapper around user-imported model and evaluates masked values of inputs.

# %%
from datasets import load_dataset
import numpy as np
import pandas as pd
import scipy as sp
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

import shap
import shap.benchmark as benchmark

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("max_colwidth", None)

# %% [markdown]
# ### Load Data and Model

# %%
dataset = load_dataset("emotion")

train = dataset["train"]
test = dataset["test"]

data = {"text": train["text"], "emotion": train["label"]}

data = pd.DataFrame(data)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# split/train-00000-of-00001.parquet:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# split/validation-00000-of-00001.parquet:   0%|          | 0.00/127k [00:00<?, ?B/s]
# split/test-00000-of-00001.parquet:   0%|          | 0.00/129k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("nateraw/bert-base-uncased-emotion", use_fast=True)
model = AutoModelForSequenceClassification.from_pretrained("nateraw/bert-base-uncased-emotion")
# Out:
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %% [markdown]
# ### Class Label Mapping

# %%
# set mapping between label and id
id2label = model.config.id2label
label2id = model.config.label2id
labels = sorted(label2id, key=label2id.get)

# %% [markdown]
# ### Define Score Function

# %%
def f(x):
    tv = torch.tensor([tokenizer.encode(v, padding="max_length", max_length=128, truncation=True) for v in x])
    attention_mask = (tv != 0).type(torch.int64)
    outputs = model(tv, attention_mask=attention_mask)[0].detach().numpy()
    scores = (np.exp(outputs).T / np.exp(outputs).sum(-1)).T
    val = sp.special.logit(scores)
    return val

# %% [markdown]
# ### Create Explainer Object

# %%
explainer = shap.Explainer(f, tokenizer, output_names=labels, algorithm='permutation')

# %% [markdown]
# ### Run SHAP Explanation

# %%
shap_values = explainer(data["text"][0:20])
# Out:
# PermutationExplainer explainer: 21it [09:23, 28.18s/it]

# %%
#plot the explanations
shap.plots.text(shap_values[0])
# Out:
# <div align='center'>
# <script>
#     document._hover_xddwsynazoaxonwxzuac = '_tp_xddwsynazoaxonwxzuac_output_0';
#     document._zoom_xddwsynazoaxonwxzuac = undefined;
#     function _output_onclick_xddwsynazoaxonwxzuac(i) {
#         var next_id = undefined;
#
#         if (document._zoom_xddwsynazoaxonwxzuac !== undefined) {
#             document.getElementById(document._zoom_xddwsynazoaxonwxzuac+ '_zoom').style.display = 'none';
#
#             if (document._zoom_xddwsynazoaxonwxzuac === '_tp_xddwsynazoaxonwxzuac_output_' + i) {
#                 document.getElementById(document._zoom_xddwsynazoaxonwxzuac).style.display = 'block';
#                 document.getElementById(document._zoom_xddwsynazoaxonwxzuac+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_xddwsynazoaxonwxzuac).style.display = 'none';
#                 document.getElementById(document._zoom_xddwsynazoaxonwxzuac+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_xddwsynazoaxonwxzuac !== '_tp_xddwsynazoaxonwxzuac_output_' + i) {
#             next_id = '_tp_xddwsynazoaxonwxzuac_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_xddwsynazoaxonwxzuac = next_id;
#     }
#     function _output_onmouseover_xddwsynazoaxonwxzuac(i, el) {
#         if (document._zoom_xddwsynazoaxonwxzuac !== undefined) { return; }
#         if (document._hover_xddwsynazoaxonwxzuac !== undefined) {
#             document.getElementById(document._hover_xddwsynazoaxonwxzuac + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_xddwsynazoaxonwxzuac).style.display = 'none';
#         }
#         document.getElementById('_tp_xddwsynazoaxonwxzuac_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_xddwsynazoaxonwxzuac = '_tp_xddwsynazoaxonwxzuac_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(np.float64(255.0), np.float64(13.0), np.float64(87.0), np.float64(0.7162210338680925)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_0_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(0)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(0, this);">Output 0</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(30.0), np.float64(136.0), np.float64(229.0), np.float64(0.9290552584670232)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_1_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(1)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(1, this);">Output 1</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(30.0), np.float64(136.0), np.float64(229.0), np.float64(0.9369380075262429)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_2_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(2)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(2, this);">Output 2</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(30.0), np.float64(136.0), np.float64(229.0), np.float64(0.8502277678748268)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_3_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(3)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(3, this);">Output 3</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(30.0), np.float64(136.0), np.float64(229.0), np.float64(0.9369380075262429)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_4_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(4)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(4, this);">Output 4</div>
# <div style="display: inline; border-bottom: none; background: rgba(np.float64(30.0), np.float64(136.0), np.float64(229.0), np.float64(1.0)); border-radius: 3px; padding: 0px" id="_tp_xddwsynazoaxonwxzuac_output_5_name"
#     onclick="_output_onclick_xddwsynazoaxonwxzuac(5)"
#     onmouseover="_output_onmouseover_xddwsynazoaxonwxzuac(5, this);">Output 5</div><br><br><div id='_tp_xddwsynazoaxonwxzuac_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="51.391195781634046%" y1="33" x2="51.391195781634046%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="51.391195781634046%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="38.212030793397275%" y1="33" x2="38.212030793397275%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="38.212030793397275%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="25.03286580516051%" y1="33" x2="25.03286580516051%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.03286580516051%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="11.853700816923743%" y1="33" x2="11.853700816923743%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.853700816923743%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="64.57036076987082%" y1="33" x2="64.57036076987082%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.57036076987082%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="77.74952575810758%" y1="33" x2="77.74952575810758%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.74952575810758%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">3</text><line x1="90.92869074634436%" y1="33" x2="90.92869074634436%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.92869074634436%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">5</text><line x1="45.55112711047122%" y1="33" x2="45.55112711047122%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="45.55112711047122%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.88626</text><text x="45.55112711047122%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1.88626</text><text x="45.55112711047122%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="95.05010240468299%" y1="33" x2="95.05010240468299%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="95.05010240468299%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">5.62544</text><text x="95.05010240468299%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">5.62544</text><text x="95.05010240468299%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Output 0</tspan>(inputs)</text><rect x="45.55112711047122%" width="49.49897529421177%" y="40" height="18" style="fill:rgb(np.float64(255.0), np.float64(0.0), np.float64(81.08083606031792)); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="49.68175842710048%" x2="95.05010240468299%" y1="60" y2="60" id="_fb_epxtmexpsajhhxgczsiv_ind_5" style="stroke:r

# %%
#plot summary
shap.plots.text(shap_values)

# %% [markdown]
# ### Define Metrics (Sort Order & Perturbation Method)

# %%
sort_order = "positive"
perturbation = "keep"

# %% [markdown]
# ### Benchmark Explainer

# %%
sequential_perturbation = benchmark.perturbation.SequentialPerturbation(
    explainer.model, explainer.masker, sort_order, perturbation
)
xs, ys, auc = sequential_perturbation.model_score(shap_values, data["text"][0:20])
sequential_perturbation.plot(xs, ys, auc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sequential_perturbation = benchmark.perturbation.SequentialPerturbation(
#       2     explainer.model, explainer.masker, sort_order, perturbation
#       3 )
#       4 xs, ys, auc = sequential_perturbation.model_score(shap_values, data["text"][0:20])
#       5 sequential_perturbation.plot(xs, ys, auc)
#
# AttributeError: module 'shap.benchmark' has no attribute 'perturbation'

# %%
sort_order = "negative"
perturbation = "keep"

# %%
sequential_perturbation = benchmark.perturbation.SequentialPerturbation(
    explainer.model, explainer.masker, sort_order, perturbation
)
xs, ys, auc = sequential_perturbation.model_score(shap_values, data["text"][0:20])
sequential_perturbation.plot(xs, ys, auc)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
